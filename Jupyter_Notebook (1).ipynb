# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# <h1>My Jupyter Notebook on IBM Watson Studio</h1>

# %% [markdown]
# **samuel kibret**
# computer science student

# %% [markdown]
# *I am interested in data science because it would increase my chance of getting a scholarship*

# %% [markdown]
# <h3>cell 5 will print my name</h3>

# %%
print("samuel kibret")
# Out:
# samuel kibret

# %% [markdown]
# - first bullet
# - second bullet
# - third bullet
#
#
# 1. first numbered bullet
# 2. second numbered bullet
# 3. third numbered bullet
#     1. sub bullet
#     2. second sub bullet
#
#
#
#
#
# ![notebook.jpg](attachment:72e21dfd-51f6-4093-bb00-f8832a1853f5.jpg)
